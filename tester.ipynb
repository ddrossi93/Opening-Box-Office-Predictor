# %%
import pandas as pd

# %%
weekend_box = pd.read_html('http://www.boxofficemojo.com/alltime/weekends/')[0]

# %%
weekend_box
# Out:
#                                                   0     \
# 0    > ALL TIME BOX OFFICE  Adjuster:  Actuals  Est...
# 1                                > ALL TIME BOX OFFICE
# 2    Adjuster:  Actuals  Est. Tckts  for(i=2018; i>...
# 3                                                  NaN
# 4    OPENING WEEKENDS $50+ M $40-50m $30-40m $25-30...
# 5                                                 Rank
# 6                                                    1
# 7                                                    2
# 8                                                    3
# 9                                                    4
# 10                                                   5
# 11                                                   6
# 12                                                   7
# 13                                                   8
# 14                                                   9
# 15                                                  10
# ...

# %%
weekend_box = weekend_box.iloc[5:]

# %%
weekend_box = weekend_box[[0,1,2,3,4,5,6,7,8]]

# %%
weekend_box.head()
# Out:
#       0                             1       2             3           4  \
# 5  Rank         Title (click to view)  Studio      Opening*  % of Total
# 6     1        Avengers: Infinity War      BV  $257,698,183       38.5%
# 7     2  Star Wars: The Force Awakens      BV  $247,966,675       26.5%
# 8     3      Star Wars: The Last Jedi      BV  $220,009,584       35.5%
# 9     4                Jurassic World    Uni.  $208,806,270       32.0%
#
#           5        6             7           8
# 5  Theaters     Avg.  Total Gross^      Date**
# 6      4474  $57,599  $669,568,677   4/27/2018
# 7      4134  $59,982  $936,662,225  12/18/2015
# 8      4232  $51,987  $620,181,382  12/15/2017
# 9      4274  $48,855  $652,270,625   6/12/2015

# %%
weekend_box.columns = weekend_box.iloc[0]

# %%
weekend_box = weekend_box.iloc[1:]

# %%
weekend_box = weekend_box[['Title (click to view)', 'Studio', 'Opening*', 'Date**']]

# %%
weekend_box.columns = ['Title', 'Studio', 'Opening', 'Date']

# %%
weekend_box
# Out:
#                                            Title Studio       Opening  \
# 6                         Avengers: Infinity War     BV  $257,698,183
# 7                   Star Wars: The Force Awakens     BV  $247,966,675
# 8                       Star Wars: The Last Jedi     BV  $220,009,584
# 9                                 Jurassic World   Uni.  $208,806,270
# 10                         Marvel's The Avengers     BV  $207,438,708
# 11                                 Black Panther     BV  $202,003,951
# 12                       Avengers: Age of Ultron     BV  $191,271,109
# 13                                 Incredibles 2     BV  $182,687,905
# 14                    Captain America: Civil War     BV  $179,139,142
# 15                   Beauty and the Beast (2017)     BV  $174,750,616
# 16                                    Iron Man 3     BV  $174,144,585
# 17   Harry Potter and the Deathly Hallows Part 2     WB  $169,189,427
# ...

# %%
weekend_box.to_csv('opening_weeked.csv')
