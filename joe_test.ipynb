# %%
import requests as req
import pandas as pd
import json

# %%
omdb = 'http://www.omdbapi.com/?apikey=645f1125&t='

# %%
aliens = req.get(omdb + "Aliens").json()

# %%
aliens
# Out:
# {'Actors': 'Sigourney Weaver, Carrie Henn, Michael Biehn, Paul Reiser',
#  'Awards': 'Won 2 Oscars. Another 18 wins & 22 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '01 Jun 1999',
#  'Director': 'James Cameron',
#  'Genre': 'Action, Adventure, Sci-Fi',
#  'Language': 'English',
#  'Metascore': '86',
#  'Plot': 'Ellen Ripley is rescued by a deep salvage team after being in hypersleep for 57 years. The moon that the Nostromo visited has been colonized, but contact is lost. This time, colonial marines have impressive firepower, but will that be enough?',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BYzVlMWViZGEtYjEyYy00YWZmLThmZGEtYmM4MDZlN2Q5MmRmXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#  'Production': '20th Century Fox Film Corporat',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.4/10'},
#   {'Source': 'Rotten Tomatoes', 'Value': '98%'},
#   {'Source': 'Metacritic', 'Value': '86/100'}],
# ...

# %%
data = pd.read_csv('box_office_data.csv')

# %%
data
# Out:
#      Unnamed: 0                                           Title Studio  \
# 0             0                          Avengers: Infinity War     BV
# 1             1                    Star Wars: The Force Awakens     BV
# 2             2                        Star Wars: The Last Jedi     BV
# 3             3                                  Jurassic World   Uni.
# 4             4                           Marvel's The Avengers     BV
# 5             5                                   Black Panther     BV
# 6             6                         Avengers: Age of Ultron     BV
# 7             7                                   Incredibles 2     BV
# 8             8                      Captain America: Civil War     BV
# 9             9                     Beauty and the Beast (2017)     BV
# 10           10                                      Iron Man 3     BV
# 11           11     Harry Potter and the Deathly Hallows Part 2     WB
# ...
